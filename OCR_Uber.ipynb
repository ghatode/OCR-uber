# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd=r"C:/Program Files/Tesseract-OCR/tesseract.exe"

# %%
from PIL import Image
import pytesseract
import os
import pandas as pd

# Path is given for for 64 bit installer
pytesseract.pytesseract.tesseract_cmd = "C:/Program Files/Tesseract-OCR/tesseract.exe"

f = []
t = []
input_dir = r'C:/Users/lenovo/Videos/intershala/Stone/Uber/Uber_in/Original/'

for root, dirs, filenames in os.walk(input_dir):
    for filename in filenames:
        try:
            print(filename)
            f.append(filename)
            image = Image.open(input_dir+ filename)
            image_to_text = pytesseract.image_to_string(image, lang = 'eng')
            t.append(image_to_text)
            print(image_to_text)
            print('-='*20)
        except:
            continue


df = pd.DataFrame(list(zip(f, t)),columns=['file_Name','Text'])
# Out:
# 0.jpg
# Uber Sun, Nov 24, 2019
#
# Here's your receipt for your trip
#
# We hope you enjoyed your ride this morning.
#
#
#
#
#
# Total 235
# Trip fare 248.91
# Subtotal 248.91
# Promotions 213.91
# Before Taxes 232,68
# CGST (2.5%) 21.16
# SGST/UTGST (2.5%) 21.16
#
# Amount Charged
#
# {Sd paid in cash 335
#
# Visit the trip page for more information, including invoices (where available)
#
# You rade with Mahaveer prasad
#
# License Plate; RJ26SQ1495
#
# Moto 6.46 kilometres | 10 min(s)
#
# 9:58 | C-20, Sawai Mansingh Rd, Satya Vihar, Krishna Nagar |, Lalkothi, Jaipur, Rajasthan
# 302015, India
#
# 10:10 | Madho Singh Rd, Bani Park, Jaipur, Rajasthan 302016, India
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# 1.csv
# 1.jpg
# Uber ous tevans ani
#
# Here's your receipt for your trip
#
# re TRG: Ata enn fanyaenl finan the: ISVS PACH OH TPN
#
#
#
# Total 235
# ‘Flv Pear: aot
# sae al Pea
# (Phang 71399
# Iiefranie: ances 268
# CORT aK) 71.16
# SHCIST AUIMGIET (C2 Sim) r16
# ...

# %%
import re
import pandas as pd
def images(string):
    image_to_text = pytesseract.image_to_string(image, lang='eng')
    date = re.search("([A-Za-z]{3}(\:)(\s)[A-Za-z]{3}(\s)[0-9]{2}(\:)(\s)[0-9]{4})",image_to_text)
    text = re.findall('[0-9.]+',image_to_text)
    total = text[3]
    tripfare = text[4]
    subtotal = text[5]
    bookingfee = text[6]
    promotion = text[4]
    print(text)
    df = pd.DataFrame({'Date':date,'Total':total,'Tripfare':tripfare,'Subtotal':subtotal,'Bookingfee':bookingfee,'Promotion':promotion},index=[0])
    df.to_csv('999.csv',index=False)
images(image)
# Out:
# ['4', '2019', '273', '278.125', '280.325', '4.325', '2765', '2.5', '21.5125', '2.5', '1.5125', '873', '14', '3324', '45', '10', '01', '23', '01', '33']
